# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

# %%
df = pd.read_csv("C:/Users/prath/Downloads/Algerian_forest_fires_dataset_UPDATE.csv",header=1)         ## remove the header

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
# dtypes: object(14)
# memory usage: 27.0+ KB

# %% [markdown]
# ## cleaning

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# dtype: int64

# %%
df.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 241    False
# 242    False
# 243    False
# 244    False
# 245    False
# Length: 246, dtype: bool

# %%
df[df.isnull().any(axis=1)]
# Out:
#                                day month  year Temperature   RH   Ws Rain   \
# 122  Sidi-Bel Abbes Region Dataset   NaN   NaN         NaN  NaN  NaN   NaN
# 167                             14    07  2012          37   37   18   0.2
#
#      FFMC   DMC      DC   ISI   BUI      FWI Classes
# 122   NaN   NaN     NaN   NaN   NaN      NaN       NaN
# 167  88.9  12.9  14.6 9  12.5  10.4  fire          NaN

# %%
## two region are in dataset

# %%
df.loc[:122,"Region"] = 0
df.loc[122:,"Region"] = 1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    float64
# dtypes: float64(1), object(14)
# memory usage: 29.0+ KB

# %%
df[['Region']] = df[['Region']].astype(int)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 246 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          246 non-null    object
#  1   month        245 non-null    object
#  2   year         245 non-null    object
#  3   Temperature  245 non-null    object
#  4    RH          245 non-null    object
#  5    Ws          245 non-null    object
#  6   Rain         245 non-null    object
#  7   FFMC         245 non-null    object
#  8   DMC          245 non-null    object
#  9   DC           245 non-null    object
#  10  ISI          245 non-null    object
#  11  BUI          245 non-null    object
#  12  FWI          245 non-null    object
#  13  Classes      244 non-null    object
#  14  Region       246 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 29.0+ KB

# %%
df.isnull().sum()
# Out:
# day            0
# month          1
# year           1
# Temperature    1
#  RH            1
#  Ws            1
# Rain           1
# FFMC           1
# DMC            1
# DC             1
# ISI            1
# BUI            1
# FWI            1
# Classes        2
# Region         0
# dtype: int64

# %%
### remove the Null values
df = df.dropna().reset_index(drop=True)

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
#  RH            0
#  Ws            0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          0
# ...

# %%
df.iloc[[122]]
# Out:
#      day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI  \
# 122  day  month  year  Temperature   RH   Ws  Rain   FFMC  DMC  DC  ISI  BUI
#
#      FWI  Classes    Region
# 122  FWI  Classes         1

# %%
df = df.drop(122).reset_index(drop=True)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 238  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 239  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 240  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 241  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 242  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes    Region
# 0    0.5   not fire          0
# ...

# %%
df.iloc[[122]]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC   DC  ISI  BUI  FWI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5  8.2  0.6  2.8  0.2
#
#        Classes    Region
# 122  not fire          1

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'Region'],
#       dtype='object')

# %%
######### Fix spaces in columns names
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    object
#  1   month        243 non-null    object
#  2   year         243 non-null    object
#  3   Temperature  243 non-null    object
#  4   RH           243 non-null    object
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(1), object(14)
# memory usage: 28.6+ KB

# %%
### Change required columns as INTEGER
df[['month','day','year','Temperature','RH']] = df[['month','day','year','Temperature','RH']].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    object
#  6   Rain         243 non-null    object
#  7   FFMC         243 non-null    object
#  8   DMC          243 non-null    object
#  9   DC           243 non-null    object
#  10  ISI          243 non-null    object
#  11  BUI          243 non-null    object
#  12  FWI          243 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: int64(6), object(9)
# memory usage: 28.6+ KB

# %%
### Changing the Other Columns to float data typw
objects = [features for features in df.columns if df[features].dtypes == 'O']

# %%
for i in objects:
    if i!= 'Classes':
        df[i] = df[i].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 243 entries, 0 to 242
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          243 non-null    int64
#  1   month        243 non-null    int64
#  2   year         243 non-null    int64
#  3   Temperature  243 non-null    int64
#  4   RH           243 non-null    int64
#  5   Ws           243 non-null    float64
#  6   Rain         243 non-null    float64
#  7   FFMC         243 non-null    float64
#  8   DMC          243 non-null    float64
#  9   DC           243 non-null    float64
#  10  ISI          243 non-null    float64
#  11  BUI          243 non-null    float64
#  12  FWI          243 non-null    float64
#  13  Classes      243 non-null    object
#  14  Region       243 non-null    int64
# dtypes: float64(8), int64(6), object(1)
# memory usage: 28.6+ KB

# %%
objects
# Out:
# ['Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes']

# %%
df.describe()
# Out:
#               day       month    year  Temperature          RH          Ws  \
# count  243.000000  243.000000   243.0   243.000000  243.000000  243.000000
# mean    15.761317    7.502058  2012.0    32.152263   62.041152   15.493827
# std      8.842552    1.114793     0.0     3.628039   14.828160    2.811385
# min      1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%      8.000000    7.000000  2012.0    30.000000   52.500000   14.000000
# 50%     16.000000    8.000000  2012.0    32.000000   63.000000   15.000000
# 75%     23.000000    8.000000  2012.0    35.000000   73.500000   17.000000
# max     31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
#              Rain        FFMC         DMC          DC         ISI         BUI  \
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean     0.762963   77.842387   14.680658   49.430864    4.742387   16.690535
# ...

# %%
### lets save the Cleaned dataset
df.to_csv("New_data_fire",index = False)

# %% [markdown]
# ### Exploratory Data Analysis

# %%
### drop the unnecessary columns like Day, Month , Year

df_copy = df.drop(['day','month','year'],axis = 1)

# %%
df_copy
# Out:
#      Temperature  RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  \
# 0             29  57  18.0   0.0  65.7   3.4   7.6  1.3   3.4  0.5
# 1             29  61  13.0   1.3  64.4   4.1   7.6  1.0   3.9  0.4
# 2             26  82  22.0  13.1  47.1   2.5   7.1  0.3   2.7  0.1
# 3             25  89  13.0   2.5  28.6   1.3   6.9  0.0   1.7  0.0
# 4             27  77  16.0   0.0  64.8   3.0  14.2  1.2   3.9  0.5
# ..           ...  ..   ...   ...   ...   ...   ...  ...   ...  ...
# 238           30  65  14.0   0.0  85.4  16.0  44.5  4.5  16.9  6.5
# 239           28  87  15.0   4.4  41.1   6.5   8.0  0.1   6.2  0.0
# 240           27  87  29.0   0.5  45.9   3.5   7.9  0.4   3.4  0.2
# 241           24  54  18.0   0.1  79.7   4.3  15.2  1.7   5.1  0.7
# 242           24  64  15.0   0.2  67.3   3.8  16.5  1.2   4.8  0.5
#
#           Classes  Region
# 0     not fire          0
# 1     not fire          0
# 2     not fire          0
# 3     not fire          0
# ...

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
## Encoding of the categories in Classes
import numpy as np
df_copy['Classes'] = np.where(df_copy['Classes'].str.contains('not fire'),0,1)

# %%
df_copy.head()
# Out:
#    Temperature  RH    Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  Classes  \
# 0           29  57  18.0   0.0  65.7  3.4   7.6  1.3  3.4  0.5        0
# 1           29  61  13.0   1.3  64.4  4.1   7.6  1.0  3.9  0.4        0
# 2           26  82  22.0  13.1  47.1  2.5   7.1  0.3  2.7  0.1        0
# 3           25  89  13.0   2.5  28.6  1.3   6.9  0.0  1.7  0.0        0
# 4           27  77  16.0   0.0  64.8  3.0  14.2  1.2  3.9  0.5        0
#
#    Region
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df_copy['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %% [markdown]
# ### Visualization

# %%
sns.set()  # Apply seaborn style
df_copy.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
### percentage Of the Fire or mot
pr = df_copy['Classes'].value_counts(normalize = True) * 100

# %%
classlabels = ["Fire","Not Fire"]
plt.figure(figsize=(12,7))
plt.pie(pr,labels=classlabels,autopct='%1.1f%%')
plt.show()

# %%
#### Correlation
df_copy.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
sns.heatmap(df_copy.corr())
# Out:
# <Axes: >

# %%
## Box plots
sns.boxplot(df_copy['FWI'])
# Out:
# <Axes: ylabel='FWI'>

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH    Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18.0   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13.0   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22.0  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13.0   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16.0   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI      Classes  Region
# 0  0.5  not fire          0
# 1  0.4  not fire          0
# 2  0.1  not fire          0
# 3  0.0  not fire          0
# 4  0.5  not fire          0

# %%
#### Monthly Fire Analysis      Here we use the df we need months
## Encoding of the categories in Classes
import numpy as np
df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[124], line 4
#       1 #### Monthly Fire Analysis      Here we use the df we need months
#       2 ## Encoding of the categories in Classes
#       3 import numpy as np
# ----> 4 df['Classes'] = np.where(df['Classes'].str.contains('not fire'),0,1)
#       5 df_temp = df.loc[df['Region'] == 1]
#       6 plt.subplots(figsize=(13,6))
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# ...

# %%
dftemp = df.loc[df['Region'] == 1]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data = dftemp)
plt.title("Sidi Bayle Region")
plt.xlabel("Months")
plt.ylabel("No.of the Fire")
# Out:
# Text(0, 0.5, 'No.of the Fire')

# %%
dftemp = df.loc[df['Region'] == 0]
plt.subplots(figsize=(13,6))
sns.set_style('whitegrid')
sns.countplot(x='month',hue='Classes',data = dftemp)
plt.title("Beerjaya Region")
plt.xlabel("Months")
plt.ylabel("No.of the Fire")
# Out:
# Text(0, 0.5, 'No.of the Fire')

# %% [markdown]
# ##### Feature Selection

# %%
df = pd.read_csv("./New_data_fire")

# %%
df
# Out:
#      day  month  year  Temperature  RH    Ws  Rain  FFMC   DMC    DC  ISI  \
# 0      1      6  2012           29  57  18.0   0.0  65.7   3.4   7.6  1.3
# 1      2      6  2012           29  61  13.0   1.3  64.4   4.1   7.6  1.0
# 2      3      6  2012           26  82  22.0  13.1  47.1   2.5   7.1  0.3
# 3      4      6  2012           25  89  13.0   2.5  28.6   1.3   6.9  0.0
# 4      5      6  2012           27  77  16.0   0.0  64.8   3.0  14.2  1.2
# ..   ...    ...   ...          ...  ..   ...   ...   ...   ...   ...  ...
# 238   26      9  2012           30  65  14.0   0.0  85.4  16.0  44.5  4.5
# 239   27      9  2012           28  87  15.0   4.4  41.1   6.5   8.0  0.1
# 240   28      9  2012           27  87  29.0   0.5  45.9   3.5   7.9  0.4
# 241   29      9  2012           24  54  18.0   0.1  79.7   4.3  15.2  1.7
# 242   30      9  2012           24  64  15.0   0.2  67.3   3.8  16.5  1.2
#
#       BUI  FWI       Classes  Region
# 0     3.4  0.5   not fire          0
# ...

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# dtype: int64

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
df.drop(['day', 'month', 'year'],axis = 1,inplace=True)   ## axis 1 delte full column  a

# %%
df['Classes'].value_counts()
# Out:
# Classes
# fire             131
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: count, dtype: int64

# %%
df["Classes"] = np.where(df['Classes'].str.contains('not fire'),0,1)

# %%
df
# Out:
#      Temperature  RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  FWI  Classes  \
# 0             29  57  18.0   0.0  65.7   3.4   7.6  1.3   3.4  0.5        0
# 1             29  61  13.0   1.3  64.4   4.1   7.6  1.0   3.9  0.4        0
# 2             26  82  22.0  13.1  47.1   2.5   7.1  0.3   2.7  0.1        0
# 3             25  89  13.0   2.5  28.6   1.3   6.9  0.0   1.7  0.0        0
# 4             27  77  16.0   0.0  64.8   3.0  14.2  1.2   3.9  0.5        0
# ..           ...  ..   ...   ...   ...   ...   ...  ...   ...  ...      ...
# 238           30  65  14.0   0.0  85.4  16.0  44.5  4.5  16.9  6.5        1
# 239           28  87  15.0   4.4  41.1   6.5   8.0  0.1   6.2  0.0        0
# 240           27  87  29.0   0.5  45.9   3.5   7.9  0.4   3.4  0.2        0
# 241           24  54  18.0   0.1  79.7   4.3  15.2  1.7   5.1  0.7        0
# 242           24  64  15.0   0.2  67.3   3.8  16.5  1.2   4.8  0.5        0
#
#      Region
# 0         0
# 1         0
# 2         0
# ...

# %%
df['Classes'].value_counts()
# Out:
# Classes
# 1    137
# 0    106
# Name: count, dtype: int64

# %%
### independent and dependemt 

x  = df.drop('FWI',axis =1)
y = df['FWI']

# %%
x
# Out:
#      Temperature  RH    Ws  Rain  FFMC   DMC    DC  ISI   BUI  Classes  Region
# 0             29  57  18.0   0.0  65.7   3.4   7.6  1.3   3.4        0       0
# 1             29  61  13.0   1.3  64.4   4.1   7.6  1.0   3.9        0       0
# 2             26  82  22.0  13.1  47.1   2.5   7.1  0.3   2.7        0       0
# 3             25  89  13.0   2.5  28.6   1.3   6.9  0.0   1.7        0       0
# 4             27  77  16.0   0.0  64.8   3.0  14.2  1.2   3.9        0       0
# ..           ...  ..   ...   ...   ...   ...   ...  ...   ...      ...     ...
# 238           30  65  14.0   0.0  85.4  16.0  44.5  4.5  16.9        1       1
# 239           28  87  15.0   4.4  41.1   6.5   8.0  0.1   6.2        0       1
# 240           27  87  29.0   0.5  45.9   3.5   7.9  0.4   3.4        0       1
# 241           24  54  18.0   0.1  79.7   4.3  15.2  1.7   5.1        0       1
# 242           24  64  15.0   0.2  67.3   3.8  16.5  1.2   4.8        0       1
#
# [243 rows x 11 columns]

# %%
y
# Out:
# 0      0.5
# 1      0.4
# 2      0.1
# 3      0.0
# 4      0.5
#       ...
# 238    6.5
# 239    0.0
# 240    0.2
# 241    0.7
# 242    0.5
# Name: FWI, Length: 243, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size = 0.8,random_state=42)

# %%
x_train.shape,x_test.shape
# Out:
# ((194, 11), (49, 11))

# %%
### feature select based on the Coreelation
df.corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
# Classes         0.516015 -0.432161 -0.069964 -0.379097  0.769492  0.585658
# ...

# %%
## check multicolinerarity
plt.figure(figsize=(12,7))
corr = x_train.corr()
sns.heatmap(corr,annot = True)
# Out:
# <Axes: >

# %%
def correlation(dataset,thrs):
    col_corr = set()
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i,j]) > thrs:         # iloc[ like FWI and ISI] > 0.80
                colname = corr_matrix.columns[i]
                col_corr.add(colname)
    return col_corr

# %%
## threshold set
cf = correlation(x_train,0.85)

# %%
## drop this ehen corr is greater than 0.85
x_train.drop(cf,axis=1,inplace=True)
x_test.drop(cf,axis=1,inplace=True)
x_train.shape,x_test.shape
# Out:
# ((194, 9), (49, 9))

# %% [markdown]
# #### Feature Scaling and Standardization

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x_train_sc = sc.fit_transform(x_train)
x_test_sc = sc.transform(x_test)

# %%
x_test_sc
# Out:
# array([[-0.32677059,  0.14650162, -0.2352019 , -0.38015572,  0.61070375,
#         -0.07699537,  0.17532762,  0.8738629 , -1.01036297],
#        [ 0.22209084, -0.52066537, -0.99568804, -0.38015572,  0.71720269,
#         -0.40637763,  0.33729694,  0.8738629 , -1.01036297],
#        [-1.15006273, -0.25379858,  0.90552731,  0.6761624 , -1.02228009,
#         -0.91960114, -0.86590375, -1.14434427,  0.98974332],
#        [ 0.49652155, -0.25379858, -0.99568804, -0.2841268 ,  0.09950881,
#          0.26770699, -0.65765748, -1.14434427,  0.98974332],
#        [-0.60120131,  0.21321832, -0.61544497, -0.38015572,  0.51840466,
#          0.06088557, -0.10233408,  0.8738629 ,  0.98974332],
#        [ 1.86867512,  0.14650162, -2.51666033,  0.1960178 , -0.30518719,
#         -0.26849668, -0.88904223, -1.14434427,  0.98974332],
#        [-1.15006273,  0.8803853 ,  0.14504117, -0.38015572,  0.29120691,
#         -0.82768051, -0.37999578,  0.8738629 ,  0.98974332],
# ...

# %%
## check outlers to check effect of the standardization

plt.subplots(figsize = (15,5))
plt.subplot(1,2,1)
sns.boxplot(data= x_train)
plt.title("X_train before scaling")
plt.subplot(1,2,2)
sns.boxplot(data= x_train_sc)
plt.title("X_train after scaling")
# Out:
# Text(0.5, 1.0, 'X_train after scaling')

# %% [markdown]
# ### Model Training

# %%
## Linear Regression

from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
model.fit(x_train_sc,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test_sc)

# %%
from sklearn.metrics import r2_score,mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
r2= r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9805895859259883

# %%
mae
# Out:
# 0.5049978694165663

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# #### LASSO Regression

# %%
from sklearn.linear_model import Lasso
model1 = Lasso()

# %%
model1.fit(x_train_sc,y_train)
# Out:
# Lasso()

# %%
y_pred = model1.predict(x_test_sc)

# %%
model1.score(x_test_sc,y_test)
# Out:
# 0.9430507350726562

# %%
from sklearn.metrics import r2_score,mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
r2= r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9430507350726562

# %%
mae
# Out:
# 1.0093958923873407

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ##### Ridge Regression Model

# %%
from sklearn.linear_model import Ridge
model2 = Ridge()

# %%
model2
# Out:
# Ridge()

# %%
model2.fit(x_train_sc,y_train)
# Out:
# Ridge()

# %%
y_pred = model2.predict(x_test_sc)

# %%
model2.score(x_test_sc,y_test)
# Out:
# 0.9801058063273602

# %%
from sklearn.metrics import r2_score,mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
r2= r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9801058063273602

# %%
mae
# Out:
# 0.5192048325844728

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ### Elastic NET regression (COMBO)

# %%
from sklearn.linear_model import ElasticNet
model3 = ElasticNet()

# %%
model3.fit(x_train_sc,y_train)
# Out:
# ElasticNet()

# %%
model3.score(x_test_sc,y_test)
# Out:
# 0.8676961352267807

# %%
from sklearn.metrics import r2_score,mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
r2= r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9801058063273602

# %%
mae
# Out:
# 0.5192048325844728

# %%
plt.scatter(y_test,y_pred)

# %% [markdown]
# ### Hyperparameter Tunning  and Cross Validation With Lasso

# %%
from sklearn.linear_model import LassoCV
lasso = LassoCV(cv = 5)

# %%
lasso.fit(x_train_sc,y_train)
# Out:
# LassoCV(cv=5)

# %%
y_pred = lasso.predict(x_test_sc)

# %%
lasso.alphas_
# Out:
# array([7.1563667 , 6.67405153, 6.2242428 , 5.80474966, 5.41352896,
#        5.04867523, 4.70841142, 4.39108025, 4.09513613, 3.81913766,
#        3.56174057, 3.32169117, 3.09782031, 2.88903759, 2.69432612,
#        2.51273756, 2.34338746, 2.18545099, 2.0381589 , 1.90079382,
#        1.77268667, 1.65321353, 1.54179247, 1.43788081, 1.34097246,
#        1.2505954 , 1.16630946, 1.08770411, 1.01439649, 0.94602956,
#        0.88227033, 0.82280827, 0.76735374, 0.71563667, 0.66740515,
#        0.62242428, 0.58047497, 0.5413529 , 0.50486752, 0.47084114,
#        0.43910802, 0.40951361, 0.38191377, 0.35617406, 0.33216912,
#        0.30978203, 0.28890376, 0.26943261, 0.25127376, 0.23433875,
#        0.2185451 , 0.20381589, 0.19007938, 0.17726867, 0.16532135,
#        0.15417925, 0.14378808, 0.13409725, 0.12505954, 0.11663095,
#        0.10877041, 0.10143965, 0.09460296, 0.08822703, 0.08228083,
#        0.07673537, 0.07156367, 0.06674052, 0.06224243, 0.0580475 ,
# ...

# %%
lasso.mse_path_
# Out:
# array([[68.58934997, 64.28650232, 49.25415197, 79.11474083, 38.68688171],
#        [63.2664675 , 58.77362304, 43.20292636, 77.07183352, 34.66910628],
#        [56.87389457, 51.79652473, 37.15764773, 69.4806422 , 31.16497557],
#        [51.2737596 , 45.69461734, 31.98560721, 62.80993539, 27.46286399],
#        [45.36816855, 40.35928545, 27.56726322, 56.94442062, 23.75447628],
#        [39.875005  , 35.69250404, 23.79907917, 50.31847875, 20.54655878],
#        [35.0794232 , 31.60885664, 20.59132915, 44.35263414, 17.77349727],
#        [30.89154006, 28.0342798 , 17.86626498, 39.14265375, 15.37720198],
#        [27.23334321, 24.90389594, 15.55674604, 34.59116894, 13.30754905],
#        [24.03652419, 22.16129069, 13.60451947, 30.61376519, 11.52101422],
#        [21.24273995, 19.75730052, 11.95924131, 27.13693185,  9.97950732],
#        [18.80004176, 17.64896267, 10.57738151, 24.09623192,  8.65087048],
#        [16.66356323, 15.79916526,  9.42117661, 21.43679316,  7.50627555],
# ...

# %%
plt.scatter(y_pred,y_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
r2= r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.978328234520343

# %%
mae
# Out:
# 0.5556715031617872

# %% [markdown]
# ### ridge Regression CV

# %%
from sklearn.linear_model import RidgeCV
rdg = RidgeCV(cv = 5)

# %%
rdg.fit(x_train_sc,y_train)
# Out:
# RidgeCV(cv=5)

# %%
y_pred =rdg.predict(x_test_sc)

# %%
plt.scatter(y_pred,y_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
r2= r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9722193780965628

# %%
mae
# Out:
# 0.68692620082771

# %%
rdg.alphas
# Out:
# (0.1, 1.0, 10.0)

# %%
rdg.get_params()
# Out:
# {'alpha_per_target': False,
#  'alphas': (0.1, 1.0, 10.0),
#  'cv': 5,
#  'fit_intercept': True,
#  'gcv_mode': None,
#  'scoring': None,
#  'store_cv_results': None,
#  'store_cv_values': 'deprecated'}

# %% [markdown]
# ### Elastic Net CV

# %%
from sklearn.linear_model import ElasticNetCV
ecv = ElasticNetCV(cv = 5)

# %%
ecv.fit(x_train_sc,y_train)
# Out:
# ElasticNetCV(cv=5)

# %%
y_pred =rdg.predict(x_test_sc)

# %%
plt.scatter(y_pred,y_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error
mae = mean_absolute_error(y_test,y_pred)
r2= r2_score(y_test,y_pred)

# %%
r2
# Out:
# 0.9722193780965628

# %%
mae
# Out:
# 0.68692620082771

# %%
ecv.l1_ratio
# Out:
# 0.5

# %%
ecv.alphas_
# Out:
# array([14.31273339, 13.34810307, 12.44848559, 11.60949933, 10.82705793,
#        10.09735046,  9.41682284,  8.78216049,  8.19027227,  7.63827533,
#         7.12348114,  6.64338235,  6.19564061,  5.77807517,  5.38865224,
#         5.02547512,  4.68677492,  4.37090197,  4.07631781,  3.80158763,
#         3.54537335,  3.30642705,  3.08358493,  2.87576163,  2.68194492,
#         2.50119081,  2.33261892,  2.17540821,  2.02879298,  1.89205912,
#         1.76454067,  1.64561653,  1.53470749,  1.43127334,  1.33481031,
#         1.24484856,  1.16094993,  1.08270579,  1.00973505,  0.94168228,
#         0.87821605,  0.81902723,  0.76382753,  0.71234811,  0.66433823,
#         0.61956406,  0.57780752,  0.53886522,  0.50254751,  0.46867749,
#         0.4370902 ,  0.40763178,  0.38015876,  0.35453733,  0.33064271,
#         0.30835849,  0.28757616,  0.26819449,  0.25011908,  0.23326189,
#         0.21754082,  0.2028793 ,  0.18920591,  0.17645407,  0.16456165,
# ...
